# %%
nombre = "jose" # Tipo de dato String (cadena de caractrese)

print ( nombre )
# Out:
# jose

# %% [markdown]
# # Tipos de datos en Phyton
# ### Tipos simples
# -str --> String cadena de caracteres.
# -int --> Numeros enteros
# -float --> numeros con notacion de punto flotante
# -complex --> Numeros complejos
# -bool --> Booleano ( True o Fals )
# -byte --> 8 bits
#
# ### Tipos de datos estructurados (compuestos)
#
#
# -list ==> Listas
# - diet ==> diccionarios
# -set y frozenset ==> conjuntos
# -tuple ==> Listas no mutables

# %%
import sys
edad = 19

print ( "Tu edad es¡",edad ) # al final de una liena de codigo

#este es un comentario de linea simple 

"""
Comenatario de multiple linea 

En lenguaje c, c++ y java el comentario de multiple linea es con: //

Aqui puedes explicar en prosa el segmento de un codigo para futura referencia

"""
# tipos de datos numericos int y float 

print(sys.getsyzeof(edad))

  # el tipo de dato INT utiliza diferente cantidad de bits segun el 
  # leg de prog. por ejemplo en C utiliza 16 bits.

edad = edad + 1
print (edad) 

estatura = 1.56
print ( estatura)
print (sys.getsizeof (estatura))
estatura = estatura + 0.1
print( round(estatura,2) )

edad -= 1 #edad = edad - 1
print( "Tu edad es:",edad)

edad /= 2 #edad = edad / 2
print( "La mitad de tu edad es:",edad)

edad = 21
# volver a calcular la mitas de la edad pero solo dejar
# parte entera
edad = edad // 2
print ("La mitad de tu edad es:" edad)

# En la mayoria de los leng no permite operaciones entre
# diferentes tipos de datos, en python no es el caso

numero = / 2.0
print ( numero )

numero *= 3
print ( numero ) # kskadkadas

numero = 5.0
numero **= 3
print ( numero )
# Out:
#   File "<ipython-input-3-55ac910909a6>", line 42
#     print ("La mitad de tu edad es:" edad)
#                                         ^
# SyntaxError: invalid syntax

# %%
# operador de modulo 
edad = 21
print( numero / 2 )
print( numero // 2)

# el operador modulo da como resultado el residuo de una divisoon entero
print( numero % 2 )

numero = 24 
print("Residuo de 24 / 5:" , numero % 5 )

#operadores relacionales (logicos)
print( numero % 2 == 0)

#diferencia
print("24 es diferente de 23=" , numero !=23)
print("24 es mayor que 23" , numero > 23)
print("24 es menor que 23" , numero < 23)

print("24 es mayor o igual que 24" , numero > = 23)
print("24 es mayor o menor que 24" , numero <=23)
# Out:
#   File "<ipython-input-1-f4635608b7ec>", line 20
#     print("24 es mayor o igual que 24" , numero > = 23)
#                                                   ^
# SyntaxError: invalid syntax

# %%
nombre = 'Jose'
carrera = "Ingenieria en computación"
frase = """ El conocimiento
me persigue,...
per
yo soy más rápido
"""
print(nombre)
print(carrera)
print(frase)

# La funcion type de Python te devuelve el tipo de dato de una variables
print(type(nombre))
print(nombre)

paterno = str( "Peréz" )
print(type(paterno))
print(paterno)
# Out:
# Jose
# Ingenieria en computación
#  El conocimiento
# me persigue,...
# per
# yo soy más rápido
#
# <class 'str'>
# Jose
# <class 'str'>
# Peréz
